# %% [markdown]
# # 1 解压文件

# %%
# %%bash
# raw_data_folder="../data/raw_data"
# unzip_data_folder="../data/unzip_data"
#
# ls $raw_data_folder
# unzip -o -d $unzip_data_folder $raw_data_folder/clicks_test.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/clicks_train.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/documents_categories.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/documents_entities.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/documents_meta.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/documents_topics.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/events.csv.zip
# #unzip -o -d $unzip_data_folder $raw_data_folder/page_views.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/page_views_sample.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/promoted_content.csv.zip
# unzip -o -d $unzip_data_folder $raw_data_folder/sample_submission.csv.zip
# echo "********$unzip_data_folder********"
# ls -al $unzip_data_folder
# Out:
# clicks_test.csv.zip
# clicks_train.csv.zip
# documents_categories.csv.zip
# documents_entities.csv.zip
# documents_meta.csv.zip
# documents_topics.csv.zip
# events.csv.zip
# page_views.csv.zip
# page_views_sample.csv.zip
# promoted_content.csv.zip
# sample_submission.csv.zip
# Archive:  ../data/raw_data/clicks_test.csv.zip
#   inflating: ../data/unzip_data/clicks_test.csv
# Archive:  ../data/raw_data/clicks_train.csv.zip
#   inflating: ../data/unzip_data/clicks_train.csv
# Archive:  ../data/raw_data/documents_categories.csv.zip
#   inflating: ../data/unzip_data/documents_categories.csv
# Archive:  ../data/raw_data/documents_entities.csv.zip
#   inflating: ../data/unzip_data/documents_entities.csv
# Archive:  ../data/raw_data/documents_meta.csv.zip
#   inflating: ../data/unzip_data/documents_meta.csv
# Archive:  ../data/raw_data/documents_topics.csv.zip
#   inflating: ../data/unzip_data/documents_topics.csv
# Archive:  ../data/raw_data/events.csv.zip
# ...

# %%
# %%bash
# raw_data_folder="../data/raw_data"
# unzip_data_folder="../data/unzip_data"
#
# wc -l  $unzip_data_folder/clicks_test.csv
# head  $unzip_data_folder/clicks_test.csv
# wc -l  $unzip_data_folder/clicks_train.csv
# head  $unzip_data_folder/clicks_train.csv
# wc -l  $unzip_data_folder/documents_categories.csv
# head  $unzip_data_folder/documents_categories.csv
# wc -l  $unzip_data_folder/documents_entities.csv
# head  $unzip_data_folder/documents_entities.csv
# wc -l  $unzip_data_folder/documents_meta.csv
# head  $unzip_data_folder/documents_meta.csv
# wc -l  $unzip_data_folder/documents_topics.csv
# head  $unzip_data_folder/documents_topics.csv
# wc -l  $unzip_data_folder/events.csv
# head  $unzip_data_folder/events.csv
# wc -l  $unzip_data_folder/page_views_sample.csv
# head  $unzip_data_folder/page_views_sample.csv
# wc -l  $unzip_data_folder/promoted_content.csv
# head  $unzip_data_folder/promoted_content.csv
# wc -l  $unzip_data_folder/sample_submission.csv
# head  $unzip_data_folder/sample_submission.csv
# Out:
#  32225163 ../data/unzip_data/clicks_test.csv
# display_id,ad_id
# 16874594,66758
# 16874594,150083
# 16874594,162754
# 16874594,170392
# 16874594,172888
# 16874594,180797
# 16874595,8846
# 16874595,30609
# 16874595,143982
#  87141732 ../data/unzip_data/clicks_train.csv
# display_id,ad_id,clicked
# 1,42337,0
# 1,139684,0
# 1,144739,1
# 1,156824,0
# 1,279295,0
# 1,296965,0
# 2,125211,0
# 2,156535,0
# 2,169564,0
#  5481476 ../data/unzip_data/documents_categories.csv
# document_id,category_id,confidence_level
# 1595802,1611,0.92
# 1595802,1610,0.07
# 1524246,1807,0.92
# 1524246,1608,0.07
# 1617787,1807,0.92
# 1617787,1608,0.07
# 1615583,1305,0.92
# 1615583,1806,0.07
# 1615460,1613,0.540646372
#  5537553 ../data/unzip_data/documents_entities.csv
# document_id,entity_id,confidence_level
# 1524246,f9eec25663db4cd83183f5c805186f16,0.672865314504701
# 1524246,55ebcfbdaff1d6f60b3907151f38527a,0.399113728441297
# 1524246,839907a972930b17b125eb0247898412,0.392095749652966
# ...

# %%
RAW_DATA_FOLDER="../data/raw_data"
